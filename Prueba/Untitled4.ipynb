# %%
# Descargar el archivo zip
# !wget https://www.py4e.com/code3/opengeo.zip

# Descomprimir
# !unzip -o opengeo.zip
# Out:
# --2025-05-09 22:19:38--  https://www.py4e.com/code3/opengeo.zip
# Resolving www.py4e.com (www.py4e.com)... 172.67.133.177, 104.21.5.179, 2606:4700:3034::ac43:85b1, ...
# Connecting to www.py4e.com (www.py4e.com)|172.67.133.177|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14317 (14K) [application/zip]
# Saving to: ‘opengeo.zip’
#
# opengeo.zip         100%[===================>]  13.98K  --.-KB/s    in 0.02s
#
# 2025-05-09 22:19:39 (690 KB/s) - ‘opengeo.zip’ saved [14317/14317]
#
# Archive:  opengeo.zip
#    creating: opengeo/
#   inflating: opengeo/README.txt
#   inflating: opengeo/where.data
#   inflating: opengeo/where.html
#   inflating: opengeo/where.js
#   inflating: opengeo/geodump.py
#   inflating: opengeo/geoload.py

# %%
# Sobrescribir el archivo where.data con direcciones nuevas
direcciones = """South Federal University
Universidad de Buenos Aires
Parque Central de Lima"""  # Aquí va una dirección cercana

with open("where.data", "w") as f:
    f.write(direcciones)

# %%
# !python3 geoload.py
# Out:
# python3: can't open file '/content/geoload.py': [Errno 2] No such file or directory

# %%
# Descargar y descomprimir correctamente el archivo zip
# !wget -O opengeo.zip https://www.py4e.com/code3/opengeo.zip
# !unzip -o opengeo.zip

# Listar archivos para confirmar que están
# !ls
# Out:
# --2025-05-09 22:21:59--  https://www.py4e.com/code3/opengeo.zip
# Resolving www.py4e.com (www.py4e.com)... 104.21.5.179, 172.67.133.177, 2606:4700:3036::6815:5b3, ...
# Connecting to www.py4e.com (www.py4e.com)|104.21.5.179|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14317 (14K) [application/zip]
# Saving to: ‘opengeo.zip’
#
# opengeo.zip         100%[===================>]  13.98K  --.-KB/s    in 0s
#
# 2025-05-09 22:21:59 (97.6 MB/s) - ‘opengeo.zip’ saved [14317/14317]
#
# Archive:  opengeo.zip
#   inflating: opengeo/README.txt
#   inflating: opengeo/where.data
#   inflating: opengeo/where.html
#   inflating: opengeo/where.js
#   inflating: opengeo/geodump.py
#   inflating: opengeo/geoload.py
# opengeo  opengeo.zip  sample_data  where.data

# %%
# !python3 opengeo/geoload.py
# Out:
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=South+Federal+University
# Retrieved 1327 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Universidad+de+Buenos+Aires
# Retrieved 1490 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Parque+Central+de+Lima
# Retrieved 1598 characters {"type":"FeatureColl
# Run geodump.py to read the data from the database so you can vizualize it on a map.

# %%
# !python3 opengeo/geodump.py
# Out:
# Federal University Lokoja 7.792138 6.731998
# Universidad de Buenos Aires -34.508711500000004 -58.68837906432547
# Parque Central Santa Rosa de Lima 14.389004 -90.295049
# 3 records written to where.js
# Open where.html to view the data in a browser

# %%
# !ls opengeo
# Out:
# geodump.py  geoload.py	README.txt  where.data	where.html  where.js

# %%
# !tail opengeo/where.data
# Out:
# Zagazig University
# allama iqbal open university islamabad
# arizona state university
# federal institute of tecnology and education from southeastern Minas Gerais
# kansas state university
# universidad complutense de madrid
# university of Patras
# university of padua
#
# Plaza San Martín, Lima, Perú

# %%
# !python3 opengeo/geodump.py
# Out:
# Federal University Lokoja 7.792138 6.731998
# Universidad de Buenos Aires -34.508711500000004 -58.68837906432547
# Parque Central Santa Rosa de Lima 14.389004 -90.295049
# 3 records written to where.js
# Open where.html to view the data in a browser

# %%
from google.colab import files
files.download('opengeo/where.html')

# %%
# Ver el contenido original
# !cat opengeo/where.data
# Out:
# AGH University of Science and Technology
# Academy of Fine Arts Warsaw Poland
# American University in Cairo
# Arizona State University
# Athens Information Technology
# BITS Pilani
# Babcock University
# Banaras Hindu University
# Bangalore University
# Baylor University
# Beijing normal university
# Belarusian State University
# Belgrade University
# Beloit College
# Belorussian State University
# Ben Gurion University
# Boston University
# California Polytechnic State University of San Luis Obispo
# California State University San Bernardino
# City of Westminster College
# Columbia University
# Cranfield University
# Czech Technical University in Prague
# De Anza College
# Dnipropetrovsk National University
# University of Texas at Austin
# Duke University
# EM Lyon
# Ecole centrale de PARIS
# Elon University
# Erhvervsakademi Sydvest
# Escuela Superior Politecnica del Litoral
# Fachhochschule Dusseldorf
# Fachhochschule FH Salzburg
# Faculty of Technical Sciences Novi Sad Serbia
# ...

# %%
with open('opengeo/where.data', 'a') as f:
    f.write('\nPlaza San Martín, Lima, Perú')  # ⚠️ Cambia esto por tu dirección real, pero sin revelar tu casa exacta

# %%
# !python3 opengeo/geoload.py
# Out:
# Found in database South Federal University
#
# Found in database Universidad de Buenos Aires
#
# Found in database Parque Central de Lima
# Run geodump.py to read the data from the database so you can vizualize it on a map.

# %%
# !python3 opengeo/geodump.py
# Out:
# Federal University Lokoja 7.792138 6.731998
# Universidad de Buenos Aires -34.508711500000004 -58.68837906432547
# Parque Central Santa Rosa de Lima 14.389004 -90.295049
# 3 records written to where.js
# Open where.html to view the data in a browser

# %%
from google.colab import files
files.download('opengeo/where.html')

# %%
# !cat opengeo/where.data
# Out:
# AGH University of Science and Technology
# Academy of Fine Arts Warsaw Poland
# American University in Cairo
# Arizona State University
# Athens Information Technology
# BITS Pilani
# Babcock University
# Banaras Hindu University
# Bangalore University
# Baylor University
# Beijing normal university
# Belarusian State University
# Belgrade University
# Beloit College
# Belorussian State University
# Ben Gurion University
# Boston University
# California Polytechnic State University of San Luis Obispo
# California State University San Bernardino
# City of Westminster College
# Columbia University
# Cranfield University
# Czech Technical University in Prague
# De Anza College
# Dnipropetrovsk National University
# University of Texas at Austin
# Duke University
# EM Lyon
# Ecole centrale de PARIS
# Elon University
# Erhvervsakademi Sydvest
# Escuela Superior Politecnica del Litoral
# Fachhochschule Dusseldorf
# Fachhochschule FH Salzburg
# Faculty of Technical Sciences Novi Sad Serbia
# ...

# %%
with open('opengeo/where.data', 'a') as f:
    f.write('\nPlaza San San Miguel, Lima, Perú')  # ⚠️ Cambia esto por tu dirección real, pero sin revelar tu casa exacta

# %%
# !python3 opengeo/geoload.py
# Out:
# Found in database South Federal University
#
# Found in database Universidad de Buenos Aires
#
# Found in database Parque Central de Lima
# Run geodump.py to read the data from the database so you can vizualize it on a map.

# %%
# !python3 opengeo/geodump.py
# Out:
# Federal University Lokoja 7.792138 6.731998
# Universidad de Buenos Aires -34.508711500000004 -58.68837906432547
# Parque Central Santa Rosa de Lima 14.389004 -90.295049
# 3 records written to where.js
# Open where.html to view the data in a browser

# %%
from google.colab import files
files.download('opengeo/where.html')

# %%
# Añadir una dirección personalizada al final del archivo where.data
with open("opengeo/where.data", "a") as f:
    f.write("\nPlaza San Martín, Lima, Perú")  # Puedes cambiar esta por otra ubicación cercana
